# %% [markdown]
# <a href="https://colab.research.google.com/github/Subliminal01/SpeechToText/blob/main/Copy_of_voice_to_text_whisper_ai.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Install Whisper

# %%
# install openai's whisper
# !pip install git+https://github.com/openai/whisper.git

# update the packages
# !sudo apt update && sudo apt install ffmpeg
# Out:
# ...
#   Cloning https://github.com/openai/whisper.git to /tmp/pip-req-build-5ite__cp
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/whisper.git /tmp/pip-req-build-5ite__cp
#   Resolved https://github.com/openai/whisper.git to commit b91c907694f96a3fb9da03d4bbdc83fbcd3a40a4
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 64.8 MB/s eta 0:00:00
# ...
#   Created wheel for openai-whisper: filename=openai_whisper-20230314-py3-none-any.whl size=798285 sha256=edb3825702fc336ddcf25ed5e989f1013ce2dd3d3303ece27263e4bc3c2e484b
#   Stored in directory: /tmp/pip-ephem-wheel-cache-a95np41i/wheels/8b/6c/d0/622666868c179f156cf595c8b6f06f88bc5d80c4b31dccaa03
# Successfully built openai-whisper
# ...
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu focal-cran40/ InRelease [3,622 B]
# ...

# %% [markdown]
# # Upload .WAV file and change the directory, then run it 👌

# %%
# Run Whisper AI:
# !whisper '/content/overthinking wav file.wav' --model medium.en

# Additional arguments:
# !whisper -h
# Out:
# [00:00.000 --> 00:06.000]  Overthinking, one of the biggest causes of unhappiness today has taken over all of the world.
# [00:06.000 --> 00:10.000]  It is now taking a toll on individuals of every age group.
# [00:10.000 --> 00:14.000]  What makes it more dangerous is that one cannot even recognize just by looking at a person's face
# [00:14.000 --> 00:19.000]  if he is not okay or needs any help and how anxiety, depression, panic attacks have taken over him.
# [00:19.000 --> 00:22.000]  Overthinking doesn't seem much dangerous just by looking at its name.
# [00:22.000 --> 00:25.000]  Overthinking is what we all do every time.
# usage: whisper
#        [-h]
#        [--model {tiny.en,tiny,base.en,base,small.en,small,medium.en,medium,large-v1,large-v2,large}]
#        [--model_dir MODEL_DIR]
#        [--device DEVICE]
#        [--output_dir OUTPUT_DIR]
#        [--output_format {txt,vtt,srt,tsv,json,all}]
#        [--verbose VERBOSE]
#        [--task {transcribe,translate}]
# ...

# %%
# to get all the requirements (basically to prepare requirements.txt file)
# !pip freeze
# Out:
# absl-py==1.4.0
# aiohttp==3.8.4
# aiosignal==1.3.1
# alabaster==0.7.13
# albumentations==1.2.1
# altair==4.2.2
# anyio==3.7.0
# appdirs==1.4.4
# argon2-cffi==21.3.0
# argon2-cffi-bindings==21.2.0
# array-record==0.4.0
# arviz==0.15.1
# astropy==5.2.2
# astunparse==1.6.3
# async-timeout==4.0.2
# attrs==23.1.0
# audioread==3.0.0
# autograd==1.6.1
# Babel==2.12.1
# backcall==0.2.0
# beautifulsoup4==4.11.2
# bleach==6.0.0
# blis==0.7.9
# blosc2==2.0.0
# bokeh==2.4.3
# branca==0.6.0
# build==0.10.0
# CacheControl==0.13.1
# cached-property==1.5.2
# cachetools==5.3.1
# catalogue==2.0.8
# certifi==2023.5.7
# cffi==1.15.1
# chardet==4.0.0
# charset-normalizer==2.0.12
# chex==0.1.7
# click==8.1.3
# click-plugins==1.1.1
# cligj==0.7.2
# cloudpickle==2.2.1
# cmake==3.25.2
# cmdstanpy==1.1.0
# colorcet==3.0.1
# colorlover==0.3.0
# community==1.0.0b1
# confection==0.0.4
# cons==0.4.6
# contextlib2==0.6.0.post1
# contourpy==1.1.0
# convertdate==2.4.0
# cufflinks==0.17.3
# cupy-cuda11x==11.0.0
# ...
